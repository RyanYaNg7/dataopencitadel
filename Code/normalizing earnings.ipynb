# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

earnings = pd.read_csv("earnings_updated_fips.csv")

earnings.head()
# Out:
# C:\Users\Public\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (8,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0          geo_id  fips                   county  total_med  \
# 0           0  0500000US01001  1001  Autauga County, Alabama      31811
# 1           1  0500000US01003  1003  Baldwin County, Alabama      30099
# 2           2  0500000US01005  1005  Barbour County, Alabama      23504
# 3           3  0500000US01007  1007     Bibb County, Alabama      30453
# 4           4  0500000US01009  1009   Blount County, Alabama      30739
#
#   total_agri_fish_mine agri_fish_hunt mining_quarrying_oilgas_extract  \
# 0                31793          31957                           22357
# 1                33173          27342                           80938
# 2                16167          14464                           27500
# ...

# %%
earnings.fillna(0, inplace=True)
earnings.replace(['2,500-', '250,000+'], [1500, 300000], inplace = True)

# %%
earnings.set_index(earnings.columns.values[0], inplace = True)
earnings.set_index(earnings.columns.values[0], inplace = True)
earnings.set_index(earnings.columns.values[0], inplace = True)
earnings
# Out:
#                              county  total_med total_agri_fish_mine  \
# fips
# 1001        Autauga County, Alabama      31811                31793
# 1003        Baldwin County, Alabama      30099                33173
# 1005        Barbour County, Alabama      23504                16167
# 1007           Bibb County, Alabama      30453                45237
# 1009         Blount County, Alabama      30739                26909
# 1011        Bullock County, Alabama      23676                23684
# 1013         Butler County, Alabama      24174                37240
# 1015        Calhoun County, Alabama      28435                22760
# 1017       Chambers County, Alabama      25886                21250
# 1019       Cherokee County, Alabama      28430                41000
# 1021        Chilton County, Alabama      30331                33451
# 1023        Choctaw County, Alabama      27514                46149
# 1025         Clarke County, Alabama      29542                28421
# ...

# %%
selected_earnings = earnings.drop(columns = ['county', 'total_med', 'year'])
s = selected_earnings.astype('float') 
s
# Out:
#        total_agri_fish_mine  agri_fish_hunt  mining_quarrying_oilgas_extract  \
# fips
# 1001                31793.0         31957.0                          22357.0
# 1003                33173.0         27342.0                          80938.0
# 1005                16167.0         14464.0                          27500.0
# 1007                45237.0         46064.0                          34406.0
# 1009                26909.0         25610.0                          54375.0
# 1011                23684.0         23684.0                              0.0
# 1013                37240.0         38170.0                              0.0
# 1015                22760.0         22794.0                          22679.0
# 1017                21250.0         21458.0                              0.0
# 1019                41000.0         41500.0                          14423.0
# 1021                33451.0         28077.0                          45469.0
# ...

# %%
s =s.div(s.sum(axis=1), axis=0)

#selected_earnings["sum"] = selected_earnings.sum(axis = 1)

# %%
normalized = pd.concat([s, earnings['year']], axis = 1)

# %%
normalized
# Out:
#        total_agri_fish_mine  agri_fish_hunt  mining_quarrying_oilgas_extract  \
# fips
# 1001               0.038453        0.038651                         0.027040
# 1003               0.038482        0.031718                         0.093891
# 1005               0.026422        0.023638                         0.044943
# 1007               0.054425        0.055420                         0.041394
# 1009               0.033389        0.031778                         0.067470
# 1011               0.039810        0.039810                         0.000000
# 1013               0.053413        0.054747                         0.000000
# 1015               0.032432        0.032480                         0.032316
# 1017               0.033473        0.033801                         0.000000
# 1019               0.053501        0.054154                         0.018821
# 1021               0.042588        0.035746                         0.057889
# ...

# %%
normalized.to_csv('normalized_earnings.csv')
